# %% [markdown]
# ### Test the raster image dataloader

# %%
import torch
from torch.utils.data import Dataset, DataLoader 
import numpy as np
import raster_relight as rr
import raster_dataloader as rd
import open3d as o3d
from matplotlib import pyplot as plt
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
ds = rd.RasterDataset()
# Out:
# lights were: {'arealightfront': array([-0.5555622 , -2.45276117,  1.72257519]), 'arealightup': array([-0.61223924,  0.67499626,  1.56039059])}
# Loading data from image ./train/r_000
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_000.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 141720 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_000_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_000_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 80410 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_000_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 24558 54
# Got depth_alpha from 0 to 156 with mean of 22.64606875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 99 to 255 with mean of 232.35393125. The datatype is uint8
# After normalizing got depth_normalized from 0.38823529411764707 to 1.0 with mean of 0.9111918872549021. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 111880 occupied pixels.
# Loaded /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/lights_chair_intrinsic.json. Number of lights is 2
# Normal pixels range from 1 to 255
# Normals pixels shape: (111880, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 111880)
# world_normals shape after reshaping to camera_normals.shape: (111880, 3)
# Posed_points shape in porject func: (111880, 3)
# in compute_raster: posed_points - (111880, 3), light_location: (3,)
# shapes: l_v:(111880, 3), l_l : (3,), p_p : (111880, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9995854878518418)]
# in raster: raster type is float64 and range in [(0.0, 0.9943712660810942)]
# in compute_raster: posed_points - (111880, 3), light_location: (3,)
# shapes: l_v:(111880, 3), l_l : (3,), p_p : (111880, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9998113069012841)]
# in raster: raster type is float64 and range in [(0.0, 0.9985982486918894)]
# Appending 111880 samples from image 0 per light.
# Appending 223760 samples from image 0.
# New number of samples after loading image 0 is 223760
# Loading data from image ./train/r_001
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_001.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 242162 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_001_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_001_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 97586 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_001_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 26439 54
# Got depth_alpha from 0 to 143 with mean of 31.4016109375. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 112 to 255 with mean of 223.5983890625. The datatype is uint8
# After normalizing got depth_normalized from 0.4392156862745098 to 1.0 with mean of 0.8768564276960784. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 157892 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (157892, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 157892)
# world_normals shape after reshaping to camera_normals.shape: (157892, 3)
# Posed_points shape in porject func: (157892, 3)
# in compute_raster: posed_points - (157892, 3), light_location: (3,)
# shapes: l_v:(157892, 3), l_l : (3,), p_p : (157892, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999994539963809)]
# in raster: raster type is float64 and range in [(0.0, 0.9999994539963809)]
# in compute_raster: posed_points - (157892, 3), light_location: (3,)
# shapes: l_v:(157892, 3), l_l : (3,), p_p : (157892, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.99999126461286)]
# in raster: raster type is float64 and range in [(0.0, 0.9911538528087291)]
# Appending 157892 samples from image 1 per light.
# Appending 315784 samples from image 1.
# New number of samples after loading image 1 is 539544
# Loading data from image ./train/r_002
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_002.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 259551 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_002_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_002_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 97188 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_002_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 29765 54
# Got depth_alpha from 0 to 172 with mean of 35.6544859375. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 83 to 255 with mean of 219.3455140625. The datatype is uint8
# After normalizing got depth_normalized from 0.3254901960784314 to 1.0 with mean of 0.8601784865196079. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 174049 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (174049, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 174049)
# world_normals shape after reshaping to camera_normals.shape: (174049, 3)
# Posed_points shape in porject func: (174049, 3)
# in compute_raster: posed_points - (174049, 3), light_location: (3,)
# shapes: l_v:(174049, 3), l_l : (3,), p_p : (174049, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999956905462146)]
# in raster: raster type is float64 and range in [(0.0, 0.9999956905462146)]
# in compute_raster: posed_points - (174049, 3), light_location: (3,)
# shapes: l_v:(174049, 3), l_l : (3,), p_p : (174049, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999829526514642)]
# in raster: raster type is float64 and range in [(0.0, 0.9999692529223708)]
# Appending 174049 samples from image 2 per light.
# Appending 348098 samples from image 2.
# New number of samples after loading image 2 is 887642
# Loading data from image ./train/r_003
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_003.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 245980 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_003_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_003_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 96571 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_003_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 28650 54
# Got depth_alpha from 0 to 142 with mean of 33.408646875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 113 to 255 with mean of 221.591353125. The datatype is uint8
# After normalizing got depth_normalized from 0.44313725490196076 to 1.0 with mean of 0.8689856985294117. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 167801 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (167801, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 167801)
# world_normals shape after reshaping to camera_normals.shape: (167801, 3)
# Posed_points shape in porject func: (167801, 3)
# in compute_raster: posed_points - (167801, 3), light_location: (3,)
# shapes: l_v:(167801, 3), l_l : (3,), p_p : (167801, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999981308887625)]
# in raster: raster type is float64 and range in [(0.0, 0.9999981308887625)]
# in compute_raster: posed_points - (167801, 3), light_location: (3,)
# shapes: l_v:(167801, 3), l_l : (3,), p_p : (167801, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999992898286154)]
# in raster: raster type is float64 and range in [(0.0, 0.99720719936413)]
# Appending 167801 samples from image 3 per light.
# Appending 335602 samples from image 3.
# New number of samples after loading image 3 is 1223244
# Loading data from image ./train/r_004
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_004.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 246053 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_004_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_004_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 90674 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_004_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 27560 54
# Got depth_alpha from 0 to 169 with mean of 32.9862796875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 86 to 255 with mean of 222.0137203125. The datatype is uint8
# After normalizing got depth_normalized from 0.33725490196078434 to 1.0 with mean of 0.8706420404411765. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 159139 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (159139, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 159139)
# world_normals shape after reshaping to camera_normals.shape: (159139, 3)
# Posed_points shape in porject func: (159139, 3)
# in compute_raster: posed_points - (159139, 3), light_location: (3,)
# shapes: l_v:(159139, 3), l_l : (3,), p_p : (159139, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999986332982632)]
# in raster: raster type is float64 and range in [(0.0, 0.9999986332982632)]
# in compute_raster: posed_points - (159139, 3), light_location: (3,)
# shapes: l_v:(159139, 3), l_l : (3,), p_p : (159139, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999996806656848)]
# in raster: raster type is float64 and range in [(0.0, 0.9999448166949373)]
# Appending 159139 samples from image 4 per light.
# Appending 318278 samples from image 4.
# New number of samples after loading image 4 is 1541522
# Loading data from image ./train/r_005
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_005.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 217226 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_005_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_005_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 80594 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_005_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 27964 54
# Got depth_alpha from 0 to 192 with mean of 40.4155328125. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 63 to 255 with mean of 214.5844671875. The datatype is uint8
# After normalizing got depth_normalized from 0.24705882352941178 to 1.0 with mean of 0.8415077144607845. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 183679 occupied pixels.
# Normal pixels range from 0 to 255
# Normals pixels shape: (183679, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 183679)
# world_normals shape after reshaping to camera_normals.shape: (183679, 3)
# Posed_points shape in porject func: (183679, 3)
# in compute_raster: posed_points - (183679, 3), light_location: (3,)
# shapes: l_v:(183679, 3), l_l : (3,), p_p : (183679, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999998063444258)]
# in raster: raster type is float64 and range in [(0.0, 0.9999998063444258)]
# in compute_raster: posed_points - (183679, 3), light_location: (3,)
# shapes: l_v:(183679, 3), l_l : (3,), p_p : (183679, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999967445213078)]
# in raster: raster type is float64 and range in [(0.0, 0.9999777708400455)]
# Appending 183679 samples from image 5 per light.
# Appending 367358 samples from image 5.
# New number of samples after loading image 5 is 1908880
# Loading data from image ./train/r_006
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_006.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 124751 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_006_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_006_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 72207 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_006_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 23583 54
# Got depth_alpha from 0 to 156 with mean of 26.985903125. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 99 to 255 with mean of 228.014096875. The datatype is uint8
# After normalizing got depth_normalized from 0.38823529411764707 to 1.0 with mean of 0.894172928921569. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 130086 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (130086, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 130086)
# world_normals shape after reshaping to camera_normals.shape: (130086, 3)
# Posed_points shape in porject func: (130086, 3)
# in compute_raster: posed_points - (130086, 3), light_location: (3,)
# shapes: l_v:(130086, 3), l_l : (3,), p_p : (130086, 3)
# in raster: albedo type is float64 and range in [(0.11372549019607843, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999694902666842)]
# in raster: raster type is float64 and range in [(0.0, 0.914827311368534)]
# in compute_raster: posed_points - (130086, 3), light_location: (3,)
# shapes: l_v:(130086, 3), l_l : (3,), p_p : (130086, 3)
# in raster: albedo type is float64 and range in [(0.11372549019607843, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999545292490915)]
# in raster: raster type is float64 and range in [(0.0, 0.9969798545273554)]
# Appending 130086 samples from image 6 per light.
# Appending 260172 samples from image 6.
# New number of samples after loading image 6 is 2169052
# Loading data from image ./train/r_007
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_007.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 159190 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_007_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_007_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 88803 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_007_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 24010 54
# Got depth_alpha from 0 to 147 with mean of 23.5764609375. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 108 to 255 with mean of 231.4235390625. The datatype is uint8
# After normalizing got depth_normalized from 0.4235294117647059 to 1.0 with mean of 0.9075432904411765. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 114390 occupied pixels.
# Normal pixels range from 0 to 255
# Normals pixels shape: (114390, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 114390)
# world_normals shape after reshaping to camera_normals.shape: (114390, 3)
# Posed_points shape in porject func: (114390, 3)
# in compute_raster: posed_points - (114390, 3), light_location: (3,)
# shapes: l_v:(114390, 3), l_l : (3,), p_p : (114390, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999304940130548)]
# in raster: raster type is float64 and range in [(0.0, 0.9994914835995778)]
# in compute_raster: posed_points - (114390, 3), light_location: (3,)
# shapes: l_v:(114390, 3), l_l : (3,), p_p : (114390, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999993719998103)]
# in raster: raster type is float64 and range in [(0.0, 0.9857110354758201)]
# Appending 114390 samples from image 7 per light.
# Appending 228780 samples from image 7.
# New number of samples after loading image 7 is 2397832
# Loading data from image ./train/r_008
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_008.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 159727 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_008_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_008_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 56071 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_008_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 22049 54
# Got depth_alpha from 0 to 197 with mean of 35.1158109375. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 58 to 255 with mean of 219.8841890625. The datatype is uint8
# After normalizing got depth_normalized from 0.22745098039215686 to 1.0 with mean of 0.8622909375000005. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 152018 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (152018, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 152018)
# world_normals shape after reshaping to camera_normals.shape: (152018, 3)
# Posed_points shape in porject func: (152018, 3)
# in compute_raster: posed_points - (152018, 3), light_location: (3,)
# shapes: l_v:(152018, 3), l_l : (3,), p_p : (152018, 3)
# in raster: albedo type is float64 and range in [(0.11372549019607843, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999680846018454)]
# in raster: raster type is float64 and range in [(0.0, 0.9999680846018454)]
# in compute_raster: posed_points - (152018, 3), light_location: (3,)
# shapes: l_v:(152018, 3), l_l : (3,), p_p : (152018, 3)
# in raster: albedo type is float64 and range in [(0.11372549019607843, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.999999361851187)]
# in raster: raster type is float64 and range in [(0.0, 0.9999596451793029)]
# Appending 152018 samples from image 8 per light.
# Appending 304036 samples from image 8.
# New number of samples after loading image 8 is 2701868
# Loading data from image ./train/r_009
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_009.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 169469 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_009_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_009_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 73982 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_009_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 20999 54
# Got depth_alpha from 0 to 181 with mean of 30.937415625. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 74 to 255 with mean of 224.062584375. The datatype is uint8
# After normalizing got depth_normalized from 0.2901960784313726 to 1.0 with mean of 0.878676801470588. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 138245 occupied pixels.
# Normal pixels range from 0 to 255
# Normals pixels shape: (138245, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 138245)
# world_normals shape after reshaping to camera_normals.shape: (138245, 3)
# Posed_points shape in porject func: (138245, 3)
# in compute_raster: posed_points - (138245, 3), light_location: (3,)
# shapes: l_v:(138245, 3), l_l : (3,), p_p : (138245, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9104528701246988)]
# in raster: raster type is float64 and range in [(0.0, 0.8675871296919739)]
# in compute_raster: posed_points - (138245, 3), light_location: (3,)
# shapes: l_v:(138245, 3), l_l : (3,), p_p : (138245, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999725557679255)]
# in raster: raster type is float64 and range in [(0.0, 0.9995985330806757)]
# Appending 138245 samples from image 9 per light.
# Appending 276490 samples from image 9.
# New number of samples after loading image 9 is 2978358
# Loading data from image ./train/r_010
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_010.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 168447 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_010_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_010_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 57130 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_010_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 19644 54
# Got depth_alpha from 0 to 188 with mean of 36.792428125. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 67 to 255 with mean of 218.207571875. The datatype is uint8
# After normalizing got depth_normalized from 0.2627450980392157 to 1.0 with mean of 0.8557159681372545. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 168023 occupied pixels.
# Normal pixels range from 0 to 255
# Normals pixels shape: (168023, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 168023)
# world_normals shape after reshaping to camera_normals.shape: (168023, 3)
# Posed_points shape in porject func: (168023, 3)
# in compute_raster: posed_points - (168023, 3), light_location: (3,)
# shapes: l_v:(168023, 3), l_l : (3,), p_p : (168023, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999652465472142)]
# in raster: raster type is float64 and range in [(0.0, 0.9999652465472142)]
# in compute_raster: posed_points - (168023, 3), light_location: (3,)
# shapes: l_v:(168023, 3), l_l : (3,), p_p : (168023, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999999596860599)]
# in raster: raster type is float64 and range in [(0.0, 0.9997157334072415)]
# Appending 168023 samples from image 10 per light.
# Appending 336046 samples from image 10.
# New number of samples after loading image 10 is 3314404
# Loading data from image ./train/r_011
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_011.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 186081 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_011_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_011_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 64726 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_011_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 23358 54
# Got depth_alpha from 0 to 195 with mean of 37.543896875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 60 to 255 with mean of 217.456103125. The datatype is uint8
# After normalizing got depth_normalized from 0.23529411764705882 to 1.0 with mean of 0.8527690318627452. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 165519 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (165519, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 165519)
# world_normals shape after reshaping to camera_normals.shape: (165519, 3)
# Posed_points shape in porject func: (165519, 3)
# in compute_raster: posed_points - (165519, 3), light_location: (3,)
# shapes: l_v:(165519, 3), l_l : (3,), p_p : (165519, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999797243883326)]
# in raster: raster type is float64 and range in [(0.0, 0.9999797243883326)]
# in compute_raster: posed_points - (165519, 3), light_location: (3,)
# shapes: l_v:(165519, 3), l_l : (3,), p_p : (165519, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999997182872149)]
# in raster: raster type is float64 and range in [(0.0, 0.9999870368580701)]
# Appending 165519 samples from image 11 per light.
# Appending 331038 samples from image 11.
# New number of samples after loading image 11 is 3645442
# Loading data from image ./train/r_012
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_012.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 251888 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_012_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_012_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 96741 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_012_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 30489 54
# Got depth_alpha from 0 to 180 with mean of 38.5246546875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 75 to 255 with mean of 216.4753453125. The datatype is uint8
# After normalizing got depth_normalized from 0.29411764705882354 to 1.0 with mean of 0.8489229227941174. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 187071 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (187071, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 187071)
# world_normals shape after reshaping to camera_normals.shape: (187071, 3)
# Posed_points shape in porject func: (187071, 3)
# in compute_raster: posed_points - (187071, 3), light_location: (3,)
# shapes: l_v:(187071, 3), l_l : (3,), p_p : (187071, 3)
# in raster: albedo type is float64 and range in [(0.11372549019607843, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999960630193802)]
# in raster: raster type is float64 and range in [(0.0, 0.9999959992711243)]
# in compute_raster: posed_points - (187071, 3), light_location: (3,)
# shapes: l_v:(187071, 3), l_l : (3,), p_p : (187071, 3)
# in raster: albedo type is float64 and range in [(0.11372549019607843, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999968166848674)]
# in raster: raster type is float64 and range in [(0.0, 0.9999930567917813)]
# Appending 187071 samples from image 12 per light.
# Appending 374142 samples from image 12.
# New number of samples after loading image 12 is 4019584
# Loading data from image ./train/r_013
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_013.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 199919 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_013_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_013_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 79484 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_013_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 23368 54
# Got depth_alpha from 0 to 170 with mean of 26.77318125. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 85 to 255 with mean of 228.22681875. The datatype is uint8
# After normalizing got depth_normalized from 0.3333333333333333 to 1.0 with mean of 0.8950071323529408. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 125153 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (125153, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 125153)
# world_normals shape after reshaping to camera_normals.shape: (125153, 3)
# Posed_points shape in porject func: (125153, 3)
# in compute_raster: posed_points - (125153, 3), light_location: (3,)
# shapes: l_v:(125153, 3), l_l : (3,), p_p : (125153, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.999992233327047)]
# in raster: raster type is float64 and range in [(0.0, 0.999992233327047)]
# in compute_raster: posed_points - (125153, 3), light_location: (3,)
# shapes: l_v:(125153, 3), l_l : (3,), p_p : (125153, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999793223433429)]
# in raster: raster type is float64 and range in [(0.0, 0.9998459758063439)]
# Appending 125153 samples from image 13 per light.
# Appending 250306 samples from image 13.
# New number of samples after loading image 13 is 4269890
# Loading data from image ./train/r_014
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_014.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 249179 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_014_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_014_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 102539 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_014_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 23564 54
# Got depth_alpha from 0 to 148 with mean of 29.510834375. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 107 to 255 with mean of 225.489165625. The datatype is uint8
# After normalizing got depth_normalized from 0.4196078431372549 to 1.0 with mean of 0.884271237745098. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 148803 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (148803, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 148803)
# world_normals shape after reshaping to camera_normals.shape: (148803, 3)
# Posed_points shape in porject func: (148803, 3)
# in compute_raster: posed_points - (148803, 3), light_location: (3,)
# shapes: l_v:(148803, 3), l_l : (3,), p_p : (148803, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999965173566754)]
# in raster: raster type is float64 and range in [(0.0, 0.9999965173566754)]
# in compute_raster: posed_points - (148803, 3), light_location: (3,)
# shapes: l_v:(148803, 3), l_l : (3,), p_p : (148803, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999697294529599)]
# in raster: raster type is float64 and range in [(0.0, 0.9850078452855295)]
# Appending 148803 samples from image 14 per light.
# Appending 297606 samples from image 14.
# New number of samples after loading image 14 is 4567496
# Loading data from image ./train/r_015
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_015.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 223012 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_015_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_015_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 88217 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_015_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 24394 54
# Got depth_alpha from 0 to 148 with mean of 27.461975. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 107 to 255 with mean of 227.538025. The datatype is uint8
# After normalizing got depth_normalized from 0.4196078431372549 to 1.0 with mean of 0.8923059803921572. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 129469 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (129469, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 129469)
# world_normals shape after reshaping to camera_normals.shape: (129469, 3)
# Posed_points shape in porject func: (129469, 3)
# in compute_raster: posed_points - (129469, 3), light_location: (3,)
# shapes: l_v:(129469, 3), l_l : (3,), p_p : (129469, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999989992725116)]
# in raster: raster type is float64 and range in [(0.0, 0.9999989992725116)]
# in compute_raster: posed_points - (129469, 3), light_location: (3,)
# shapes: l_v:(129469, 3), l_l : (3,), p_p : (129469, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999966383731903)]
# in raster: raster type is float64 and range in [(0.0, 0.9999966383731903)]
# Appending 129469 samples from image 15 per light.
# Appending 258938 samples from image 15.
# New number of samples after loading image 15 is 4826434
# Loading data from image ./train/r_016
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_016.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 200341 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_016_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_016_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 87944 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_016_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 26222 54
# Got depth_alpha from 0 to 146 with mean of 28.9976375. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 109 to 255 with mean of 226.0023625. The datatype is uint8
# After normalizing got depth_normalized from 0.42745098039215684 to 1.0 with mean of 0.8862837745098039. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 142447 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (142447, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 142447)
# world_normals shape after reshaping to camera_normals.shape: (142447, 3)
# Posed_points shape in porject func: (142447, 3)
# in compute_raster: posed_points - (142447, 3), light_location: (3,)
# shapes: l_v:(142447, 3), l_l : (3,), p_p : (142447, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.999999297744492)]
# in raster: raster type is float64 and range in [(0.0, 0.999999297744492)]
# in compute_raster: posed_points - (142447, 3), light_location: (3,)
# shapes: l_v:(142447, 3), l_l : (3,), p_p : (142447, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999700091555028)]
# in raster: raster type is float64 and range in [(0.0, 0.9800088571100688)]
# Appending 142447 samples from image 16 per light.
# Appending 284894 samples from image 16.
# New number of samples after loading image 16 is 5111328
# Loading data from image ./train/r_017
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_017.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# ...
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 9911 54
# Got depth_alpha from 0 to 174 with mean of 10.9292421875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 81 to 255 with mean of 244.0707578125. The datatype is uint8
# After normalizing got depth_normalized from 0.3176470588235294 to 1.0 with mean of 0.9571402267156863. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 47837 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (47837, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 47837)
# world_normals shape after reshaping to camera_normals.shape: (47837, 3)
# Posed_points shape in porject func: (47837, 3)
# in compute_raster: posed_points - (47837, 3), light_location: (3,)
# shapes: l_v:(47837, 3), l_l : (3,), p_p : (47837, 3)
# in raster: albedo type is float64 and range in [(0.11764705882352941, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999767881949848)]
# in raster: raster type is float64 and range in [(0.0, 0.9999767881949848)]
# in compute_raster: posed_points - (47837, 3), light_location: (3,)
# shapes: l_v:(47837, 3), l_l : (3,), p_p : (47837, 3)
# in raster: albedo type is float64 and range in [(0.11764705882352941, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9991869926943755)]
# in raster: raster type is float64 and range in [(0.0, 0.9983941057097876)]
# Appending 47837 samples from image 134 per light.
# Appending 95674 samples from image 134.
# New number of samples after loading image 134 is 37705086
# Loading data from image ./train/r_135
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_135.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 51390 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_135_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_135_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 30193 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_135_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 10019 54
# Got depth_alpha from 0 to 168 with mean of 9.4309078125. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 87 to 255 with mean of 245.5690921875. The datatype is uint8
# After normalizing got depth_normalized from 0.3411764705882353 to 1.0 with mean of 0.9630160477941178. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 43577 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (43577, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 43577)
# world_normals shape after reshaping to camera_normals.shape: (43577, 3)
# Posed_points shape in porject func: (43577, 3)
# in compute_raster: posed_points - (43577, 3), light_location: (3,)
# shapes: l_v:(43577, 3), l_l : (3,), p_p : (43577, 3)
# in raster: albedo type is float64 and range in [(0.12941176470588237, 0.9647058823529412)]
# in raster: shading type is float64 and range in [(0.0, 0.9999987987066563)]
# in raster: raster type is float64 and range in [(0.0, 0.9647047234581861)]
# in compute_raster: posed_points - (43577, 3), light_location: (3,)
# shapes: l_v:(43577, 3), l_l : (3,), p_p : (43577, 3)
# in raster: albedo type is float64 and range in [(0.12941176470588237, 0.9647058823529412)]
# in raster: shading type is float64 and range in [(0.0, 0.9999813285450793)]
# in raster: raster type is float64 and range in [(0.0, 0.8694753316753655)]
# Appending 43577 samples from image 135 per light.
# Appending 87154 samples from image 135.
# New number of samples after loading image 135 is 37792240
# Loading data from image ./train/r_136
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_136.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 48109 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_136_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_136_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 37392 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_136_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 11737 54
# Got depth_alpha from 0 to 159 with mean of 8.973971875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 96 to 255 with mean of 246.026028125. The datatype is uint8
# After normalizing got depth_normalized from 0.3764705882352941 to 1.0 with mean of 0.9648079534313725. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 45395 occupied pixels.
# Normal pixels range from 0 to 255
# Normals pixels shape: (45395, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 45395)
# world_normals shape after reshaping to camera_normals.shape: (45395, 3)
# Posed_points shape in porject func: (45395, 3)
# in compute_raster: posed_points - (45395, 3), light_location: (3,)
# shapes: l_v:(45395, 3), l_l : (3,), p_p : (45395, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9999830402972513)]
# in raster: raster type is float64 and range in [(0.0, 0.9995724686469876)]
# in compute_raster: posed_points - (45395, 3), light_location: (3,)
# shapes: l_v:(45395, 3), l_l : (3,), p_p : (45395, 3)
# in raster: albedo type is float64 and range in [(0.10980392156862745, 1.0)]
# in raster: shading type is float64 and range in [(0.0, 0.9934716672030117)]
# in raster: raster type is float64 and range in [(0.0, 0.9111117432532323)]
# Appending 45395 samples from image 136 per light.
# Appending 90790 samples from image 136.
# New number of samples after loading image 136 is 37883030
# Loading data from image ./train/r_137
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_137.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 36718 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_137_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_137_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 27869 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_137_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 9415 54
# Got depth_alpha from 0 to 175 with mean of 10.9344546875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 80 to 255 with mean of 244.0655453125. The datatype is uint8
# After normalizing got depth_normalized from 0.3137254901960784 to 1.0 with mean of 0.9571197855392154. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 46277 occupied pixels.
# Normal pixels range from 1 to 255
# Normals pixels shape: (46277, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 46277)
# world_normals shape after reshaping to camera_normals.shape: (46277, 3)
# Posed_points shape in porject func: (46277, 3)
# in compute_raster: posed_points - (46277, 3), light_location: (3,)
# shapes: l_v:(46277, 3), l_l : (3,), p_p : (46277, 3)
# in raster: albedo type is float64 and range in [(0.11764705882352941, 0.792156862745098)]
# in raster: shading type is float64 and range in [(0.0, 0.9999758919356394)]
# in raster: raster type is float64 and range in [(0.0, 0.5019486830108307)]
# in compute_raster: posed_points - (46277, 3), light_location: (3,)
# shapes: l_v:(46277, 3), l_l : (3,), p_p : (46277, 3)
# in raster: albedo type is float64 and range in [(0.11764705882352941, 0.792156862745098)]
# in raster: shading type is float64 and range in [(0.0, 0.9999987154847527)]
# in raster: raster type is float64 and range in [(0.0, 0.5457120742280552)]
# Appending 46277 samples from image 137 per light.
# Appending 92554 samples from image 137.
# New number of samples after loading image 137 is 37975584
# Loading data from image ./train/r_138
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_138.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 32755 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_138_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_138_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 28854 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_138_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 9269 54
# Got depth_alpha from 0 to 152 with mean of 7.482765625. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 103 to 255 with mean of 247.517234375. The datatype is uint8
# After normalizing got depth_normalized from 0.403921568627451 to 1.0 with mean of 0.9706558210784315. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 36444 occupied pixels.
# Normal pixels range from 6 to 255
# Normals pixels shape: (36444, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 36444)
# world_normals shape after reshaping to camera_normals.shape: (36444, 3)
# Posed_points shape in porject func: (36444, 3)
# in compute_raster: posed_points - (36444, 3), light_location: (3,)
# shapes: l_v:(36444, 3), l_l : (3,), p_p : (36444, 3)
# in raster: albedo type is float64 and range in [(0.12941176470588237, 0.792156862745098)]
# in raster: shading type is float64 and range in [(0.0, 0.9998685014497564)]
# in raster: raster type is float64 and range in [(0.0, 0.5018947771983091)]
# in compute_raster: posed_points - (36444, 3), light_location: (3,)
# shapes: l_v:(36444, 3), l_l : (3,), p_p : (36444, 3)
# in raster: albedo type is float64 and range in [(0.12941176470588237, 0.792156862745098)]
# in raster: shading type is float64 and range in [(0.0, 0.9997303592490308)]
# in raster: raster type is float64 and range in [(0.0, 0.501825435230886)]
# Appending 36444 samples from image 138 per light.
# Appending 72888 samples from image 138.
# New number of samples after loading image 138 is 38048472
# Loading data from image ./train/r_139
# Loading ground_truth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_139.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'tEXt' 149 94
# STREAM b'tEXt' 255 24
# STREAM b'tEXt' 291 16
# STREAM b'tEXt' 319 9
# STREAM b'tEXt' 340 13
# STREAM b'tEXt' 365 11
# STREAM b'tEXt' 388 19
# STREAM b'tEXt' 419 30
# STREAM b'tEXt' 461 38
# STREAM b'tEXt' 511 39
# STREAM b'tEXt' 562 48
# STREAM b'IDAT' 622 8192
# STREAM b'eXIf' 45137 54
# Loading normal from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_139_normal.png.
# Loading albedo from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_139_albedo.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 34498 54
# Loading depth from /home/dtetruash/Thesis/datasets/nerf-blender/nerf_synthetic/chair_intrinsic/train/r_139_depth.png.
# STREAM b'IHDR' 16 13
# STREAM b'eXIf' 41 54
# STREAM b'oFFs' 107 9
# b'oFFs' 107 9 (unknown)
# STREAM b'pHYs' 128 9
# STREAM b'IDAT' 149 8192
# STREAM b'eXIf' 10127 54
# Got depth_alpha from 0 to 173 with mean of 10.2481546875. The datatype is uint8
# Bit depth used for depth remapping was 8 and a max values of 255
# Ater remapping got depth_remapped from 82 to 255 with mean of 244.7518453125. The datatype is uint8
# After normalizing got depth_normalized from 0.3215686274509804 to 1.0 with mean of 0.9598111580882356. The datatype is float64
# Occumpancy mask of shape (800, 800), and with 45658 occupied pixels.
# Normal pixels range from 2 to 255
# Normals pixels shape: (45658, 3)
# Normals were loaded using a color depth of 8.
# world_normals_shape after posing: (3, 45658)
# world_normals shape after reshaping to camera_normals.shape: (45658, 3)
# Posed_points shape in porject func: (45658, 3)
# in compute_raster: posed_points - (45658, 3), light_location: (3,)
# shapes: l_v:(45658, 3), l_l : (3,), p_p : (45658, 3)
# in raster: albedo type is float64 and range in [(0.11764705882352941, 0.9647058823529412)]
# in raster: shading type is float64 and range in [(0.0, 0.9999485630314213)]
# in raster: raster type is float64 and range in [(0.0, 0.9612684900919387)]
# in compute_raster: posed_points - (45658, 3), light_location: (3,)
# shapes: l_v:(45658, 3), l_l : (3,), p_p : (45658, 3)
# in raster: albedo type is float64 and range in [(0.11764705882352941, 0.9647058823529412)]
# in raster: shading type is float64 and range in [(0.0, 0.999940838609056)]
# in raster: raster type is float64 and range in [(0.0, 0.7266724027751649)]
# Appending 45658 samples from image 139 per light.
# Appending 91316 samples from image 139.
# New number of samples after loading image 139 is 38139788
# Final number of samples is 38139788
# World normals array has shape (38139788, 3)
# Albedo array has shape (38139788, 3)
# Raster image array has shape (38139788, 3)
# Target array has shape (38139788, 3)

# %%
38139788 /2
# Out:
# 19069894.0
